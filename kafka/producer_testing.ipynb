# %% [markdown]
# # Testing different producers
#
# This notebook contains the code for the Producer which creates the messages. The data source is the websocket from binance (https://binance-docs.github.io/apidocs/websocket_api/en/#change-log) and the Twitter API.

# %% [markdown]
# ## Imports

# %%
from kafka import KafkaProducer, KafkaConsumer
import json
import uuid
import websocket
from datetime import datetime
import requests

url = "https://api.twitter.com/2/tweets/search/recent?query=%23crypto%20OR%20%23ethereum%20OR%20%23eth%20OR%20%23btc%20OR%20%23bitcoin&max_results=100&tweet.fields=created_at,text,author_id"

with open("secrets.env", "r") as f:
    secrets = json.loads(str(f.read()))

bearerToken = secrets['bearerToken']

# %% [markdown]
# ## Adjusting websocket code to write data directly into Kafka Cluster.

# %%
from kafka_functions import *
from datetime import datetime
import websocket
import uuid
import requests

url = "https://api.twitter.com/2/tweets/search/recent?query=%23crypto%20OR%20%23ethereum%20OR%20%23eth%20OR%20%23btc%20OR%20%23bitcoin&max_results=100&tweet.fields=created_at,text,author_id"

with open("secrets.env", "r") as f:
    secrets = json.loads(str(f.read()))

bearerToken = secrets['bearerToken']

# %%
test_array = []

def on_open(ws):
    print("Connection opened")
    # Subscribe to different ticker streams
    subscribe_message = {
        "method": "SUBSCRIBE",
        "params": [
            "btcusdt@ticker",
            "ethusdt@ticker",
            "maticusdt@ticker",
            "shibusdt@ticker",
            "solusdt@ticker"
        ],
        "id": 1
    }
    ws.send(json.dumps(subscribe_message))

def on_message(ws, message):
    # close after 3 seconds for testing
    if (datetime.now() - start).seconds > 7:
        ws.close()

    # write data into cluster
    key = str(uuid.uuid4())
    publish_message(binance_producer, binance_topic, key, json.loads(message))
    print(f"{datetime.now()}: writing message to cluster: {str(message)[:50]}...")
    
    # append data to array for testing
    test_array.append((key, json.loads(message)))

def on_close(ws):
    print("Connection closed")

binance_start = datetime.timestamp(datetime.now())

# consume messages from previous sessions
_ = consume_messages(binance_consumer)

if __name__ == "__main__":
    # Initialize WebSocket connection
    ws = websocket.WebSocketApp(
        "wss://stream.binance.com:9443/ws",
        on_open=on_open,
        on_message=on_message,
        on_close=on_close
    )
    # only for testing
    start = datetime.now()
    # Start WebSocket connection
    ws.run_forever()
# Out:
# Consumed 71 messages from Kafka Cluster
# Connection opened
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:44.676626: writing message to cluster: {"result":null,"id":1}...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:44.696084: writing message to cluster: {"e":"24hrTicker","E":1678354604586,"s":"SOLUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:45.265317: writing message to cluster: {"e":"24hrTicker","E":1678354604854,"s":"SHIBUSDT"...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:45.472696: writing message to cluster: {"e":"24hrTicker","E":1678354605308,"s":"MATICUSDT...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:45.474544: writing message to cluster: {"e":"24hrTicker","E":1678354605363,"s":"BTCUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:45.476193: writing message to cluster: {"e":"24hrTicker","E":1678354605360,"s":"ETHUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:45.714950: writing message to cluster: {"e":"24hrTicker","E":1678354605505,"s":"SOLUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:46.190621: writing message to cluster: {"e":"24hrTicker","E":1678354605683,"s":"SHIBUSDT"...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:46.494384: writing message to cluster: {"e":"24hrTicker","E":1678354606279,"s":"MATICUSDT...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:46.520846: writing message to cluster: {"e":"24hrTicker","E":1678354606356,"s":"BTCUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:46.522809: writing message to cluster: {"e":"24hrTicker","E":1678354606363,"s":"ETHUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:46.802047: writing message to cluster: {"e":"24hrTicker","E":1678354606549,"s":"SOLUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:47.211302: writing message to cluster: {"e":"24hrTicker","E":1678354606779,"s":"SHIBUSDT"...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:47.727688: writing message to cluster: {"e":"24hrTicker","E":1678354607275,"s":"MATICUSDT...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:47.729703: writing message to cluster: {"e":"24hrTicker","E":1678354607362,"s":"BTCUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:47.731416: writing message to cluster: {"e":"24hrTicker","E":1678354607299,"s":"ETHUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:47.733028: writing message to cluster: {"e":"24hrTicker","E":1678354607586,"s":"SOLUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:48.339822: writing message to cluster: {"e":"24hrTicker","E":1678354607763,"s":"SHIBUSDT"...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:48.862093: writing message to cluster: {"e":"24hrTicker","E":1678354608321,"s":"MATICUSDT...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:48.864084: writing message to cluster: {"e":"24hrTicker","E":1678354608367,"s":"BTCUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:48.865829: writing message to cluster: {"e":"24hrTicker","E":1678354608344,"s":"ETHUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:48.867512: writing message to cluster: {"e":"24hrTicker","E":1678354608574,"s":"SOLUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:49.156958: writing message to cluster: {"e":"24hrTicker","E":1678354608389,"s":"SHIBUSDT"...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:49.575883: writing message to cluster: {"e":"24hrTicker","E":1678354609295,"s":"MATICUSDT...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:49.578161: writing message to cluster: {"e":"24hrTicker","E":1678354609358,"s":"BTCUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:49.580225: writing message to cluster: {"e":"24hrTicker","E":1678354609210,"s":"ETHUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:49.713424: writing message to cluster: {"e":"24hrTicker","E":1678354609598,"s":"SOLUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:50.182880: writing message to cluster: {"e":"24hrTicker","E":1678354609763,"s":"SHIBUSDT"...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:50.488357: writing message to cluster: {"e":"24hrTicker","E":1678354610269,"s":"MATICUSDT...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:50.513967: writing message to cluster: {"e":"24hrTicker","E":1678354610355,"s":"BTCUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:50.516128: writing message to cluster: {"e":"24hrTicker","E":1678354610327,"s":"ETHUSDT",...
# Using <function <lambda> at 0x7f5bc04001f0> as value serializer.
# Using <function <lambda> at 0x7f5bc0400310> as key serializer.
# Message published successfully.
# 2023-03-09 09:36:51.146890: writing message to cluster: {"e":"24hrTicker","E":1678354610582,"s":"SOLUSDT",...

# %% [markdown]
# ### Testing produced and consumed messages

# %%
# retrieving messages
consumed_messages = consume_messages(binance_consumer)

# testing if write & read operations work as intended
for i, message in enumerate(consumed_messages):
    assert message[1] == test_array[i][1]
    assert message[0].decode('utf-8') == test_array[i][0]
print("Consumed messages match produced messages.")
# Out:
# Consumed 765 messages from Kafka Cluster
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 6
#       4 # testing if write & read operations work as intended
#       5 for i, message in enumerate(consumed_messages):
# ----> 6     assert message[1] == test_array[i][1]
#       7     assert message[0].decode('utf-8') == test_array[i][0]
#       8 print("Consumed messages match produced messages.")
#
# AssertionError:

# %% [markdown]
# ## Twitter Producer

# %%
test_array = []
start, timestamp_last_request = datetime.now(), datetime.now()

twitter_start = datetime.timestamp(datetime.now())

# consume messages from other sessions
_ = consume_messages(twitter_consumer)

if __name__ == "__main__":
    while (datetime.now() - start).seconds < 21:
        # time limit to stay within api regulations
        if (datetime.now() - timestamp_last_request).seconds > 10:
            # get tweets
            tweets = json.loads(requests.get(url=url, headers={'Authorization': f"Bearer {bearerToken}"}).text)['data']
            for tweet in tweets:
                # formatting for json serializing
                formatted_tweet = json.dumps(tweet)
                
                # write to cluster
                key = str(uuid.uuid4())
                publish_message(twitter_producer, twitter_topic, key, formatted_tweet)
                print(f"{datetime.now()}: writing message to cluster: {formatted_tweet[:50]}...")
                
                # append to test_array
                test_array.append((key, formatted_tweet))
            
            timestamp_last_request = datetime.now()
# Out:
# Consumed 105 messages from Kafka Cluster
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.529657: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.531426: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.533172: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.535804: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.537902: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.539489: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.540978: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.542501: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.544221: writing message to cluster: {"created_at": "2023-03-09T09:40:25.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.545687: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.547131: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.548673: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.550224: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.552673: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.554179: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.555689: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.557284: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.558611: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.559843: writing message to cluster: {"created_at": "2023-03-09T09:40:24.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.561206: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.562866: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.564357: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.566843: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.569006: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.570752: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.572134: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.573445: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.574849: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.576099: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.577303: writing message to cluster: {"created_at": "2023-03-09T09:40:23.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.578510: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.579861: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.581363: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.582810: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.584152: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.585469: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.586798: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.589380: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.590727: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.592063: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.593299: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.594618: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.595987: writing message to cluster: {"created_at": "2023-03-09T09:40:22.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.597144: writing message to cluster: {"created_at": "2023-03-09T09:40:21.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.598493: writing message to cluster: {"created_at": "2023-03-09T09:40:21.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.599870: writing message to cluster: {"created_at": "2023-03-09T09:40:21.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.601512: writing message to cluster: {"created_at": "2023-03-09T09:40:21.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.603512: writing message to cluster: {"created_at": "2023-03-09T09:40:21.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.604974: writing message to cluster: {"created_at": "2023-03-09T09:40:21.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.606251: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.607376: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.608525: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.609704: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.610793: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.611842: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.612897: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.613939: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.615101: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.616238: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.617375: writing message to cluster: {"created_at": "2023-03-09T09:40:20.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.618365: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.619397: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.620659: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.621731: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.622775: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.623945: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.625008: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.625997: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.626972: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.627991: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.629065: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.630075: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.631162: writing message to cluster: {"created_at": "2023-03-09T09:40:19.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.633052: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.634402: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.636189: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.637426: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.638473: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.639472: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.640605: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.641645: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.643358: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.644336: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.645267: writing message to cluster: {"created_at": "2023-03-09T09:40:18.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.646263: writing message to cluster: {"created_at": "2023-03-09T09:40:17.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.647241: writing message to cluster: {"created_at": "2023-03-09T09:40:17.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.648331: writing message to cluster: {"created_at": "2023-03-09T09:40:17.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.649453: writing message to cluster: {"created_at": "2023-03-09T09:40:17.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.650520: writing message to cluster: {"created_at": "2023-03-09T09:40:17.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.651528: writing message to cluster: {"created_at": "2023-03-09T09:40:17.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.652623: writing message to cluster: {"created_at": "2023-03-09T09:40:16.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.653791: writing message to cluster: {"created_at": "2023-03-09T09:40:16.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.654798: writing message to cluster: {"created_at": "2023-03-09T09:40:16.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.655804: writing message to cluster: {"created_at": "2023-03-09T09:40:16.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.656780: writing message to cluster: {"created_at": "2023-03-09T09:40:16.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.657741: writing message to cluster: {"created_at": "2023-03-09T09:40:16.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.658932: writing message to cluster: {"created_at": "2023-03-09T09:40:16.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.660090: writing message to cluster: {"created_at": "2023-03-09T09:40:16.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.661131: writing message to cluster: {"created_at": "2023-03-09T09:40:15.000Z", "id": "...
# Using <function <lambda> at 0x7fa23abbee60> as value serializer.
# Using <function <lambda> at 0x7fa23abbef80> as key serializer.
# Message published successfully.
# 2023-03-09 09:40:36.662143: writing message to cluster: {"created_at": "2023-03-09T09:40:15.000Z", "id": "...

# %% [markdown]
# ### Testing produced and consumed messages

# %%
# retrieve messages
consumed_messages = consume_messages(twitter_consumer)

# testing if write & read operations work as intended
for i, message in enumerate(consumed_messages):
    assert message[1] == test_array[i][1]
    assert message[0] == test_array[i][0]
print("Consumed messages match produced messages.")
# Out:
# Consumed 100 messages from Kafka Cluster
# Consumed messages match produced messages.

# %%
messages = consume_messages(twitter_consumer)
# Out:
# Consumed 700 messages from Kafka Cluster
