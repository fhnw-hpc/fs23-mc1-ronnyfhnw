# %% [markdown]
# # Producer Notebook
#
# This notebook contains the code for the Producer which creates the messages. The data source is the websocket from binance (https://binance-docs.github.io/apidocs/websocket_api/en/#change-log).

# %% [markdown]
# ## Imports

# %%
from kafka import KafkaProducer, KafkaConsumer
import json
import uuid
import websocket
from datetime import datetime
import requests

url = "https://api.twitter.com/2/tweets/search/recent?query=%23crypto%20OR%20%23ethereum%20OR%20%23eth%20OR%20%23btc%20OR%20%23bitcoin&max_results=100&tweet.fields=created_at,text,author_id"

with open("secrets.env", "r") as f:
    secrets = json.loads(str(f.read()))

bearerToken = secrets['bearerToken']

# %% [markdown]
# ## Defining functions for producing and consuming messages, defining producer and consumer

# %%
# defining connection
server1, server2, server3 = 'broker1:9093', 'broker2:9095', 'broker3:9097'
servers = [server1, server2, server3]
binance_topic, twitter_topic = "binance-ws", "twitter"

# using functions from example notebook
def connect_kafka_producer(servers):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=servers, api_version=(0, 10))
        print("Created Producer")
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer
    
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully.')
    except Exception as ex:
        print('Exception in publishing message')
        print(str(ex))

def consume_xy(consumer, topic_name):
    messages = []
    for msg in consumer:
        messages.append((msg.key.decode('utf-8'), msg.value))
    print(f"Consumed {len(messages)} messages from Kafka Cluster")
    return messages

def connect_kafka_producer(servers):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=servers, api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer

# setting up consumer for binance
binance_consumer = KafkaConsumer(binance_topic, 
                         auto_offset_reset='earliest',
                         bootstrap_servers=servers,
                         api_version=(0, 10), 
                         value_deserializer = json.loads,
                         consumer_timeout_ms=1000)

# setting up new consumer for twitter messages
twitter_consumer = KafkaConsumer(twitter_topic, 
                         auto_offset_reset='earliest',
                         bootstrap_servers=servers,
                         api_version=(0, 10), 
                         value_deserializer = json.loads,
                         consumer_timeout_ms=1000)

producer = connect_kafka_producer(servers)

# %% [markdown]
# ## Adjusting websocket code to write data directly into Kafka Cluster.

# %%
test_array = []

def on_open(ws):
    print("Connection opened")
    # Subscribe to different ticker streams
    subscribe_message = {
        "method": "SUBSCRIBE",
        "params": [
            "btcusdt@ticker",
            "ethusdt@ticker",
            "maticusdt@ticker",
            "shibusdt@ticker",
            "solusdt@ticker"
        ],
        "id": 1
    }
    ws.send(json.dumps(subscribe_message))

def on_message(ws, message):
    # close after 3 seconds for testing
    if (datetime.now() - start).seconds > 3:
        ws.close()

    # write data into cluster
    key = str(uuid.uuid4())
    publish_message(producer, binance_topic, key, message)
    print(f"{datetime.now()}: writing message to cluster: {str(message)[:50]}...")
    
    # append data to array for testing
    test_array.append((key, json.loads(message)))

def on_close(ws):
    print("Connection closed")

binance_start = datetime.timestamp(datetime.now())

# consume messages from previous sessions
_ = consume_xy(binance_consumer, twitter_topic)

if __name__ == "__main__":
    # Initialize WebSocket connection
    ws = websocket.WebSocketApp(
        "wss://stream.binance.com:9443/ws",
        on_open=on_open,
        on_message=on_message,
        on_close=on_close
    )
    # only for testing
    start = datetime.now()
    # Start WebSocket connection
    ws.run_forever()
# Out:
# Consumed 0 messages from Kafka Cluster
# Connection opened
# Message published successfully.
# 2023-03-07 11:36:51.269999: writing message to cluster: {"result":null,"id":1}...
# Message published successfully.
# 2023-03-07 11:36:51.273198: writing message to cluster: {"e":"24hrTicker","E":1678189011148,"s":"SHIBUSDT"...
# Message published successfully.
# 2023-03-07 11:36:51.498224: writing message to cluster: {"e":"24hrTicker","E":1678189011481,"s":"BTCUSDT",...
# Message published successfully.
# 2023-03-07 11:36:51.501286: writing message to cluster: {"e":"24hrTicker","E":1678189011473,"s":"ETHUSDT",...
# Message published successfully.
# 2023-03-07 11:36:51.780064: writing message to cluster: {"e":"24hrTicker","E":1678189011587,"s":"MATICUSDT...
# Message published successfully.
# 2023-03-07 11:36:51.826710: writing message to cluster: {"e":"24hrTicker","E":1678189011510,"s":"SOLUSDT",...
# Message published successfully.
# 2023-03-07 11:36:52.289921: writing message to cluster: {"e":"24hrTicker","E":1678189012256,"s":"SHIBUSDT"...
# Message published successfully.
# 2023-03-07 11:36:52.514458: writing message to cluster: {"e":"24hrTicker","E":1678189012482,"s":"BTCUSDT",...
# Message published successfully.
# 2023-03-07 11:36:52.516999: writing message to cluster: {"e":"24hrTicker","E":1678189012481,"s":"ETHUSDT",...
# Message published successfully.
# 2023-03-07 11:36:52.778214: writing message to cluster: {"e":"24hrTicker","E":1678189012750,"s":"MATICUSDT...
# Message published successfully.
# 2023-03-07 11:36:52.826375: writing message to cluster: {"e":"24hrTicker","E":1678189012750,"s":"SOLUSDT",...
# Message published successfully.
# 2023-03-07 11:36:53.298061: writing message to cluster: {"e":"24hrTicker","E":1678189012935,"s":"SHIBUSDT"...
# Message published successfully.
# 2023-03-07 11:36:53.925797: writing message to cluster: {"e":"24hrTicker","E":1678189013482,"s":"BTCUSDT",...

# %% [markdown]
# ### Testing produced and consumed messages

# %%
# retrieving messages
consumed_messages = consume_xy(binance_consumer, binance_topic)

# testing if write & read operations work as intended
for i, message in enumerate(consumed_messages):
    assert message[1] == test_array[i][1]
    assert message[0] == test_array[i][0]
print("Consumed messages match produced messages.")
# Out:
# Consumed 13 messages from Kafka Cluster
# Consumed messages match produced messages.

# %% [markdown]
# ## Twitter Producer

# %%
test_array = []
start, timestamp_last_request = datetime.now(), datetime.now()

twitter_start = datetime.timestamp(datetime.now())

# consume messages from other sessions
_ = consume_xy(twitter_consumer, twitter_topic)

if __name__ == "__main__":
    while (datetime.now() - start).seconds < 21:
        # time limit to stay within api regulations
        if (datetime.now() - timestamp_last_request).seconds > 10:
            # get tweets
            tweets = json.loads(requests.get(url=url, headers={'Authorization': f"Bearer {bearerToken}"}).text)['data']
            for tweet in tweets:
                # formatting for json serializing
                formatted_tweet = json.dumps(tweet)
                
                # write to cluster
                key = str(uuid.uuid4())
                publish_message(producer, twitter_topic, key, formatted_tweet)
                print(f"{datetime.now()}: writing message to cluster: {formatted_tweet[:50]}...")
                
                # append to test_array
                test_array.append((key, formatted_tweet))
            
            timestamp_last_request = datetime.now()
# Out:
# Consumed 1900 messages from Kafka Cluster
# Message published successfully.
# 2023-03-07 11:37:13.154971: writing message to cluster: {"author_id": "1451191701695909912", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.165359: writing message to cluster: {"author_id": "1602982306574123008", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.167047: writing message to cluster: {"author_id": "1598245017499291648", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.168276: writing message to cluster: {"author_id": "1505898808483491847", "text": "Pric...
# Message published successfully.
# 2023-03-07 11:37:13.169807: writing message to cluster: {"author_id": "1514635813543239681", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.171177: writing message to cluster: {"author_id": "1592179954275348480", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.172588: writing message to cluster: {"author_id": "1538197450728808449", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.174111: writing message to cluster: {"author_id": "1526103433673347072", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.176158: writing message to cluster: {"author_id": "1590447414615461890", "text": "#Bit...
# Message published successfully.
# 2023-03-07 11:37:13.177622: writing message to cluster: {"author_id": "2363858305", "text": "RT @blockchai...
# Message published successfully.
# 2023-03-07 11:37:13.179002: writing message to cluster: {"author_id": "335656476", "text": "Get free boxes...
# Message published successfully.
# 2023-03-07 11:37:13.180411: writing message to cluster: {"author_id": "1611373927762108418", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.181739: writing message to cluster: {"author_id": "1415480191699148802", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.183011: writing message to cluster: {"author_id": "254926519", "text": "RT @okx: #OKX1...
# Message published successfully.
# 2023-03-07 11:37:13.184236: writing message to cluster: {"author_id": "1576453936164360195", "text": "@Duc...
# Message published successfully.
# 2023-03-07 11:37:13.185509: writing message to cluster: {"author_id": "1632939340711215105", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.186824: writing message to cluster: {"author_id": "1165429175026683904", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.188044: writing message to cluster: {"author_id": "1496963575348350988", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.189436: writing message to cluster: {"author_id": "984232547797286913", "text": "RT @C...
# Message published successfully.
# 2023-03-07 11:37:13.190748: writing message to cluster: {"author_id": "1374512697966882816", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.191930: writing message to cluster: {"author_id": "1194538186308902913", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.193078: writing message to cluster: {"author_id": "1604994204345995265", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.194255: writing message to cluster: {"author_id": "1632075626483011584", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.195351: writing message to cluster: {"author_id": "867538571087020032", "text": "RT @G...
# Message published successfully.
# 2023-03-07 11:37:13.196331: writing message to cluster: {"author_id": "1295883791731290112", "text": "#Cry...
# Message published successfully.
# 2023-03-07 11:37:13.197338: writing message to cluster: {"author_id": "1613741815064297472", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.198289: writing message to cluster: {"author_id": "498690174", "text": "RT @fanswebio:...
# Message published successfully.
# 2023-03-07 11:37:13.199308: writing message to cluster: {"author_id": "1477851628279681024", "text": "@cry...
# Message published successfully.
# 2023-03-07 11:37:13.200433: writing message to cluster: {"author_id": "1405326582068224005", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.201443: writing message to cluster: {"author_id": "994262156962029570", "text": "RT @G...
# Message published successfully.
# 2023-03-07 11:37:13.202620: writing message to cluster: {"author_id": "1615036966470569984", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.203912: writing message to cluster: {"author_id": "1243521982353698817", "text": "#KuC...
# Message published successfully.
# 2023-03-07 11:37:13.205209: writing message to cluster: {"author_id": "1487807632539021312", "text": "\ud8...
# Message published successfully.
# 2023-03-07 11:37:13.206440: writing message to cluster: {"author_id": "1515685876403433473", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.207833: writing message to cluster: {"author_id": "96088658", "text": "Amazon making a...
# Message published successfully.
# 2023-03-07 11:37:13.208925: writing message to cluster: {"author_id": "1523707437672501255", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.210016: writing message to cluster: {"author_id": "1404100935274536962", "text": "Good...
# Message published successfully.
# 2023-03-07 11:37:13.211074: writing message to cluster: {"author_id": "1626795476346630145", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.212164: writing message to cluster: {"author_id": "160332876", "text": "RT @BTCTN: \"I...
# Message published successfully.
# 2023-03-07 11:37:13.213204: writing message to cluster: {"author_id": "1629395324111585282", "text": "\ud8...
# Message published successfully.
# 2023-03-07 11:37:13.214214: writing message to cluster: {"author_id": "1625900061753319424", "text": "@you...
# Message published successfully.
# 2023-03-07 11:37:13.215294: writing message to cluster: {"author_id": "1623706236897333249", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.216307: writing message to cluster: {"author_id": "1608718219837341696", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.217309: writing message to cluster: {"author_id": "1563951618973786112", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.218312: writing message to cluster: {"author_id": "1558729253176635393", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.219334: writing message to cluster: {"author_id": "2506737871", "text": "@Reen65_Samur...
# Message published successfully.
# 2023-03-07 11:37:13.220510: writing message to cluster: {"author_id": "1541438668983791616", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.221585: writing message to cluster: {"author_id": "1512286504743100421", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.222679: writing message to cluster: {"author_id": "1620846228144521227", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.223814: writing message to cluster: {"author_id": "1421124077121531909", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.224910: writing message to cluster: {"author_id": "232179997", "text": "RT @MantleSwap...
# Message published successfully.
# 2023-03-07 11:37:13.226056: writing message to cluster: {"author_id": "204086937", "text": "RT @SK__FX: FX...
# Message published successfully.
# 2023-03-07 11:37:13.227105: writing message to cluster: {"author_id": "1273707068", "text": "RT @blockchai...
# Message published successfully.
# 2023-03-07 11:37:13.228135: writing message to cluster: {"author_id": "1610326586754232325", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.229101: writing message to cluster: {"author_id": "1617883014087995395", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.230075: writing message to cluster: {"author_id": "1231319934", "text": "RT @Bitcoin: ...
# Message published successfully.
# 2023-03-07 11:37:13.231161: writing message to cluster: {"author_id": "1613545688608149507", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.232163: writing message to cluster: {"author_id": "1102162362935570432", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.233123: writing message to cluster: {"author_id": "1355519384534609926", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.234092: writing message to cluster: {"author_id": "1421344709721554944", "text": "\ud8...
# Message published successfully.
# 2023-03-07 11:37:13.235110: writing message to cluster: {"author_id": "1284390986", "text": "RT @saylor: #...
# Message published successfully.
# 2023-03-07 11:37:13.236138: writing message to cluster: {"author_id": "1603767922601922560", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.237244: writing message to cluster: {"author_id": "1481492891516166144", "text": "$ACS...
# Message published successfully.
# 2023-03-07 11:37:13.238323: writing message to cluster: {"author_id": "181699393", "text": "RT @CharonNeon...
# Message published successfully.
# 2023-03-07 11:37:13.239330: writing message to cluster: {"author_id": "2380283605", "text": "RT @saylor: \...
# Message published successfully.
# 2023-03-07 11:37:13.240365: writing message to cluster: {"author_id": "1438208437096230914", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.241472: writing message to cluster: {"author_id": "2467130593", "text": "RT @Riko_FX1:...
# Message published successfully.
# 2023-03-07 11:37:13.242424: writing message to cluster: {"author_id": "1563809989394825216", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.243388: writing message to cluster: {"author_id": "1590089513862418434", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.244361: writing message to cluster: {"author_id": "1604887778", "text": "RT @HuobiGlob...
# Message published successfully.
# 2023-03-07 11:37:13.245452: writing message to cluster: {"author_id": "1493349037776453638", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.246437: writing message to cluster: {"author_id": "1471717058081558528", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.247414: writing message to cluster: {"author_id": "1517030770618998784", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.248353: writing message to cluster: {"author_id": "1633067070202978310", "text": "#ETH...
# Message published successfully.
# 2023-03-07 11:37:13.249309: writing message to cluster: {"author_id": "551926622", "text": "RT @CoinMarket...
# Message published successfully.
# 2023-03-07 11:37:13.250275: writing message to cluster: {"author_id": "767627846126702593", "text": "RT @A...
# Message published successfully.
# 2023-03-07 11:37:13.251171: writing message to cluster: {"author_id": "921492760703541248", "text": "Ready...
# Message published successfully.
# 2023-03-07 11:37:13.252332: writing message to cluster: {"author_id": "420391942", "text": "RT @RollbitRew...
# Message published successfully.
# 2023-03-07 11:37:13.253733: writing message to cluster: {"author_id": "1415569026747494403", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.255090: writing message to cluster: {"author_id": "1072259222694490112", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.256630: writing message to cluster: {"author_id": "1395432449723838464", "text": "Requ...
# Message published successfully.
# 2023-03-07 11:37:13.258134: writing message to cluster: {"author_id": "1570456419840954368", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.259580: writing message to cluster: {"author_id": "1589312073674022912", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.260801: writing message to cluster: {"author_id": "1633067065195069444", "text": "#NFT...
# Message published successfully.
# 2023-03-07 11:37:13.262025: writing message to cluster: {"author_id": "1130322229", "text": "RT @NftRamob:...
# Message published successfully.
# 2023-03-07 11:37:13.263134: writing message to cluster: {"author_id": "744299894", "text": "@meta_launcher...
# Message published successfully.
# 2023-03-07 11:37:13.264175: writing message to cluster: {"author_id": "1631658128189329408", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.265248: writing message to cluster: {"author_id": "1453925998508982273", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.266298: writing message to cluster: {"author_id": "1536677443963977728", "text": "\ud8...
# Message published successfully.
# 2023-03-07 11:37:13.267483: writing message to cluster: {"author_id": "1009726527238336512", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.268584: writing message to cluster: {"author_id": "1483488427836420102", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.269650: writing message to cluster: {"author_id": "1447852194112458753", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.270970: writing message to cluster: {"author_id": "1571501914571014144", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.272113: writing message to cluster: {"author_id": "249437977", "text": "RT @Techconcat...
# Message published successfully.
# 2023-03-07 11:37:13.273217: writing message to cluster: {"author_id": "81835805", "text": "Goo how #QUACK ...
# Message published successfully.
# 2023-03-07 11:37:13.274326: writing message to cluster: {"author_id": "196508393", "text": "RT @FinancialM...
# Message published successfully.
# 2023-03-07 11:37:13.275436: writing message to cluster: {"author_id": "1372769613180669954", "text": "\ud8...
# Message published successfully.
# 2023-03-07 11:37:13.276427: writing message to cluster: {"author_id": "1351367444552564738", "text": "RT @...
# Message published successfully.
# 2023-03-07 11:37:13.277426: writing message to cluster: {"author_id": "2506737871", "text": "@memecoinmast...
# Message published successfully.
# 2023-03-07 11:37:13.278406: writing message to cluster: {"author_id": "1449266318952189954", "text": "\ud8...

# %% [markdown]
# ### Testing produced and consumed messages

# %%
# retrieve messages
consumed_messages = consume_xy(twitter_consumer, twitter_topic)

# testing if write & read operations work as intended
for i, message in enumerate(consumed_messages):
    assert message[1] == json.loads(test_array[i][1])
    assert message[0] == test_array[i][0]
print("Consumed messages match produced messages.")
# Out:
# Consumed 100 messages from Kafka Cluster
# Consumed messages match produced messages.
