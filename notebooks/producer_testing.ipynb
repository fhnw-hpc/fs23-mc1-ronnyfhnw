# %% [markdown]
# # Producer Notebook
#
# This notebook contains the code for the Producer which creates the messages. The data source is the websocket from binance (https://binance-docs.github.io/apidocs/websocket_api/en/#change-log).

# %% [markdown]
# ## Imports

# %%
from kafka import KafkaProducer, KafkaConsumer
import json
import uuid
import websocket
from datetime import datetime
import requests

url = "https://api.twitter.com/2/tweets/search/recent?query=%23crypto%20OR%20%23ethereum%20OR%20%23eth%20OR%20%23btc%20OR%20%23bitcoin&max_results=100&tweet.fields=created_at,text,author_id"

with open("secrets.env", "r") as f:
    secrets = json.loads(str(f.read()))

bearerToken = secrets['bearerToken']

# %% [markdown]
# ## Defining functions for producing and consuming messages, defining producer and consumer

# %%
# defining connection
server1, server2, server3 = 'broker1:9093', 'broker2:9095', 'broker3:9097'
servers = [server1, server2, server3]
binance_topic, twitter_topic = "binance-ws", "twitter"

# using functions from example notebook
def connect_kafka_producer(servers):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=servers, api_version=(0, 10))
        print("Created Producer")
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer
    
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully.')
    except Exception as ex:
        print('Exception in publishing message')
        print(str(ex))

def consume_xy(consumer, topic_name):
    messages = []
    for msg in consumer:
        messages.append((msg.key.decode('utf-8'), msg.value))
    print(f"Consumed {len(messages)} messages from Kafka Cluster")
    return messages

def connect_kafka_producer(servers):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=servers, api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer

# setting up consumer for binance
binance_consumer = KafkaConsumer(binance_topic, 
                         auto_offset_reset='earliest',
                         bootstrap_servers=servers,
                         api_version=(0, 10), 
                         value_deserializer = json.loads,
                         consumer_timeout_ms=1000)

# setting up new consumer for twitter messages
twitter_consumer = KafkaConsumer(twitter_topic, 
                         auto_offset_reset='earliest',
                         bootstrap_servers=servers,
                         api_version=(0, 10), 
                         value_deserializer = json.loads,
                         consumer_timeout_ms=1000)

producer = connect_kafka_producer(servers)

# %% [markdown]
# ## Adjusting websocket code to write data directly into Kafka Cluster.

# %%
test_array = []

def on_open(ws):
    print("Connection opened")
    # Subscribe to different ticker streams
    subscribe_message = {
        "method": "SUBSCRIBE",
        "params": [
            "btcusdt@ticker",
            "ethusdt@ticker",
            "maticusdt@ticker",
            "shibusdt@ticker",
            "solusdt@ticker"
        ],
        "id": 1
    }
    ws.send(json.dumps(subscribe_message))

def on_message(ws, message):
    # close after 3 seconds for testing
    if (datetime.now() - start).seconds > 3:
        ws.close()

    # write data into cluster
    key = str(uuid.uuid4())
    publish_message(producer, binance_topic, key, message)
    print(f"{datetime.now()}: writing message to cluster: {str(message)[:50]}...")
    
    # append data to array for testing
    test_array.append((key, json.loads(message)))

def on_close(ws):
    print("Connection closed")

binance_start = datetime.timestamp(datetime.now())

# consume messages from previous sessions

if __name__ == "__main__":
    # Initialize WebSocket connection
    ws = websocket.WebSocketApp(
        "wss://stream.binance.com:9443/ws",
        on_open=on_open,
        on_message=on_message,
        on_close=on_close
    )
    # only for testing
    start = datetime.now()
    # Start WebSocket connection
    ws.run_forever()
# Out:
# Connection opened
# Message published successfully.
# 2023-03-07 09:37:41.565465: writing message to cluster: {"result":null,"id":1}...
# Message published successfully.
# 2023-03-07 09:37:41.752278: writing message to cluster: {"e":"24hrTicker","E":1678181861245,"s":"MATICUSDT...
# Message published successfully.
# 2023-03-07 09:37:42.198294: writing message to cluster: {"e":"24hrTicker","E":1678181862086,"s":"SOLUSDT",...
# Message published successfully.
# 2023-03-07 09:37:42.246734: writing message to cluster: {"e":"24hrTicker","E":1678181862140,"s":"BTCUSDT",...
# Message published successfully.
# 2023-03-07 09:37:42.249891: writing message to cluster: {"e":"24hrTicker","E":1678181862105,"s":"ETHUSDT",...
# Message published successfully.
# 2023-03-07 09:37:42.306011: writing message to cluster: {"e":"24hrTicker","E":1678181862154,"s":"SHIBUSDT"...
# Message published successfully.
# 2023-03-07 09:37:42.754121: writing message to cluster: {"e":"24hrTicker","E":1678181862648,"s":"MATICUSDT...
# Message published successfully.
# 2023-03-07 09:37:43.200079: writing message to cluster: {"e":"24hrTicker","E":1678181863089,"s":"SOLUSDT",...
# Message published successfully.
# 2023-03-07 09:37:43.252427: writing message to cluster: {"e":"24hrTicker","E":1678181863143,"s":"BTCUSDT",...
# Message published successfully.
# 2023-03-07 09:37:43.255318: writing message to cluster: {"e":"24hrTicker","E":1678181863132,"s":"ETHUSDT",...
# Message published successfully.
# 2023-03-07 09:37:43.316688: writing message to cluster: {"e":"24hrTicker","E":1678181863158,"s":"SHIBUSDT"...
# Message published successfully.
# 2023-03-07 09:37:43.754472: writing message to cluster: {"e":"24hrTicker","E":1678181863637,"s":"MATICUSDT...
# Message published successfully.
# 2023-03-07 09:37:44.667320: writing message to cluster: {"e":"24hrTicker","E":1678181864077,"s":"SOLUSDT",...

# %% [markdown]
# ### Testing produced and consumed messages

# %%
# retrieving messages
consumed_messages = consume_xy(binance_consumer, binance_topic)

# testing if write & read operations work as intended
for i, message in enumerate(consumed_messages):
    assert message[1] == test_array[i][1]
    assert message[0] == test_array[i][0]
print("Consumed messages match produced messages.")
# Out:
# Consumed 13 messages from Kafka Cluster
# Starting message
# Consumed messages match produced messages.

# %% [markdown]
# ## Twitter Producer

# %%
test_array = []
start, timestamp_last_request = datetime.now(), datetime.now()

twitter_start = datetime.timestamp(datetime.now())

# consume messages from other sessions
_ = consume_xy(twitter_consumer, twitter_topic)

if __name__ == "__main__":
    while (datetime.now() - start).seconds < 21:
        # time limit to stay within api regulations
        if (datetime.now() - timestamp_last_request).seconds > 10:
            # get tweets
            tweets = json.loads(requests.get(url=url, headers={'Authorization': f"Bearer {bearerToken}"}).text)['data']
            for tweet in tweets:
                # formatting for json serializing
                formatted_tweet = json.dumps(tweet)
                
                # write to cluster
                key = str(uuid.uuid4())
                publish_message(producer, twitter_topic, key, formatted_tweet)
                print(f"{datetime.now()}: writing message to cluster: {formatted_tweet[:50]}...")
                
                # append to test_array
                test_array.append((key, formatted_tweet))
            
            timestamp_last_request = datetime.now()
# Out:
# Consumed 0 messages from Kafka Cluster
# Message published successfully.
# 2023-03-07 10:05:03.167936: writing message to cluster: {"id": "1633046043410718720", "text": "RT @Array_P...
# Message published successfully.
# 2023-03-07 10:05:03.170113: writing message to cluster: {"id": "1633046043162968067", "text": "RT @Crypto_...
# Message published successfully.
# 2023-03-07 10:05:03.171806: writing message to cluster: {"id": "1633046042399633412", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.173673: writing message to cluster: {"id": "1633046041963696129", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.175373: writing message to cluster: {"id": "1633046041716043779", "text": "RT @magikal...
# Message published successfully.
# 2023-03-07 10:05:03.176962: writing message to cluster: {"id": "1633046041204506626", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.178674: writing message to cluster: {"id": "1633046040537595912", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.180644: writing message to cluster: {"id": "1633046040378241025", "text": "RT @Array_P...
# Message published successfully.
# 2023-03-07 10:05:03.182279: writing message to cluster: {"id": "1633046040323538949", "text": "RT @cryptom...
# Message published successfully.
# 2023-03-07 10:05:03.183901: writing message to cluster: {"id": "1633046039862325248", "text": "RT @Memory_...
# Message published successfully.
# 2023-03-07 10:05:03.185450: writing message to cluster: {"id": "1633046039807803392", "text": "\ud83d\udcb...
# Message published successfully.
# 2023-03-07 10:05:03.186963: writing message to cluster: {"id": "1633046039631630336", "text": "RT @p2d_tow...
# Message published successfully.
# 2023-03-07 10:05:03.188636: writing message to cluster: {"id": "1633046039157669888", "text": "RT @GemVade...
# Message published successfully.
# 2023-03-07 10:05:03.190338: writing message to cluster: {"id": "1633046039132504070", "text": "@cryptoworl...
# Message published successfully.
# 2023-03-07 10:05:03.191985: writing message to cluster: {"id": "1633046039027675137", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.193697: writing message to cluster: {"id": "1633046038985732097", "text": "RT @ZahidES...
# Message published successfully.
# 2023-03-07 10:05:03.195435: writing message to cluster: {"id": "1633046038792785920", "text": "\ud83d\udcb...
# Message published successfully.
# 2023-03-07 10:05:03.197040: writing message to cluster: {"id": "1633046038788358146", "text": "RT @WiseCry...
# Message published successfully.
# 2023-03-07 10:05:03.198636: writing message to cluster: {"id": "1633046038465613824", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.200209: writing message to cluster: {"id": "1633046038427881472", "text": "@RichQuack ...
# Message published successfully.
# 2023-03-07 10:05:03.201759: writing message to cluster: {"id": "1633046038285000705", "text": "@MonstersCo...
# Message published successfully.
# 2023-03-07 10:05:03.203296: writing message to cluster: {"id": "1633046038033448961", "text": "RT @aliadar...
# Message published successfully.
# 2023-03-07 10:05:03.204744: writing message to cluster: {"id": "1633046037987225600", "text": "RT @heisfli...
# Message published successfully.
# 2023-03-07 10:05:03.206399: writing message to cluster: {"id": "1633046037886562306", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.208300: writing message to cluster: {"id": "1633046037555208193", "text": "RT @gem_rad...
# Message published successfully.
# 2023-03-07 10:05:03.209916: writing message to cluster: {"id": "1633046037475762177", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.211562: writing message to cluster: {"id": "1633046037446406147", "text": "\ud83d\udcb...
# Message published successfully.
# 2023-03-07 10:05:03.213130: writing message to cluster: {"id": "1633046037358317569", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.214768: writing message to cluster: {"id": "1633046036796125184", "text": "RT @Crypto_...
# Message published successfully.
# 2023-03-07 10:05:03.216360: writing message to cluster: {"id": "1633046036678860800", "text": "\ud83d\udcb...
# Message published successfully.
# 2023-03-07 10:05:03.217894: writing message to cluster: {"id": "1633046036431372288", "text": "RT @Memory_...
# Message published successfully.
# 2023-03-07 10:05:03.219626: writing message to cluster: {"id": "1633046036431220737", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.221518: writing message to cluster: {"id": "1633046035982598145", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.223287: writing message to cluster: {"id": "1633046035810471936", "text": "RT @gate_io...
# Message published successfully.
# 2023-03-07 10:05:03.224952: writing message to cluster: {"id": "1633046035529633793", "text": "RT @p2d_tow...
# Message published successfully.
# 2023-03-07 10:05:03.226610: writing message to cluster: {"id": "1633046035487506433", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.228320: writing message to cluster: {"id": "1633046035483308032", "text": "RT @Array_P...
# Message published successfully.
# 2023-03-07 10:05:03.229993: writing message to cluster: {"id": "1633046035416371202", "text": "\ud83c\udf8...
# Message published successfully.
# 2023-03-07 10:05:03.231738: writing message to cluster: {"id": "1633046035399593985", "text": "G\ud83d\udc...
# Message published successfully.
# 2023-03-07 10:05:03.233366: writing message to cluster: {"id": "1633046035382796294", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.234965: writing message to cluster: {"id": "1633046035114369026", "text": "[EXCLUSIVE]...
# Message published successfully.
# 2023-03-07 10:05:03.236825: writing message to cluster: {"id": "1633046035068260352", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.238509: writing message to cluster: {"id": "1633046034934034433", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.240204: writing message to cluster: {"id": "1633046034728509440", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.242006: writing message to cluster: {"id": "1633046034552061952", "text": "RT @Peer__2...
# Message published successfully.
# 2023-03-07 10:05:03.243597: writing message to cluster: {"id": "1633046034283634691", "text": "RT @QuaiNet...
# Message published successfully.
# 2023-03-07 10:05:03.244996: writing message to cluster: {"id": "1633046034078371846", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.246426: writing message to cluster: {"id": "1633046034053201921", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.248006: writing message to cluster: {"id": "1633046033499586560", "text": "RT @Memory_...
# Message published successfully.
# 2023-03-07 10:05:03.249692: writing message to cluster: {"id": "1633046033315024896", "text": "@CryptoInsi...
# Message published successfully.
# 2023-03-07 10:05:03.251281: writing message to cluster: {"id": "1633046033222574127", "text": "\ud83c\udf8...
# Message published successfully.
# 2023-03-07 10:05:03.252881: writing message to cluster: {"id": "1633046033180786688", "text": "RT @Memory_...
# Message published successfully.
# 2023-03-07 10:05:03.254363: writing message to cluster: {"id": "1633046032627167234", "text": "\ud83d\udcb...
# Message published successfully.
# 2023-03-07 10:05:03.255964: writing message to cluster: {"id": "1633046032522305542", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.257419: writing message to cluster: {"id": "1633046032169984000", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.259133: writing message to cluster: {"id": "1633046031729577984", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.260595: writing message to cluster: {"id": "1633046031532437504", "text": "RT @DBMETA_...
# Message published successfully.
# 2023-03-07 10:05:03.261924: writing message to cluster: {"id": "1633046031264002048", "text": "RT @Array_P...
# Message published successfully.
# 2023-03-07 10:05:03.263321: writing message to cluster: {"id": "1633046031087685634", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.264901: writing message to cluster: {"id": "1633046030869512192", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.266422: writing message to cluster: {"id": "1633046030827634689", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.268225: writing message to cluster: {"id": "1633046030798422016", "text": "\ud83c\udf8...
# Message published successfully.
# 2023-03-07 10:05:03.269853: writing message to cluster: {"id": "1633046030609416192", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.271514: writing message to cluster: {"id": "1633046030584274948", "text": "RT @Bitcoin...
# Message published successfully.
# 2023-03-07 10:05:03.273310: writing message to cluster: {"id": "1633046030395772928", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.275071: writing message to cluster: {"id": "1633046030089601024", "text": "RT @Coins_T...
# Message published successfully.
# 2023-03-07 10:05:03.276743: writing message to cluster: {"id": "1633046029485633543", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.278331: writing message to cluster: {"id": "1633046029061828610", "text": "RT @gate_io...
# Message published successfully.
# 2023-03-07 10:05:03.279881: writing message to cluster: {"id": "1633046029032632320", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.281379: writing message to cluster: {"id": "1633046028441235464", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.283224: writing message to cluster: {"id": "1633046028407668736", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.284854: writing message to cluster: {"id": "1633046028390907906", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.286296: writing message to cluster: {"id": "1633046028189601792", "text": "RT @oesnetw...
# Message published successfully.
# 2023-03-07 10:05:03.287689: writing message to cluster: {"id": "1633046028176744451", "text": "RT @Memory_...
# Message published successfully.
# 2023-03-07 10:05:03.289240: writing message to cluster: {"id": "1633046027703025664", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.291045: writing message to cluster: {"id": "1633046027283619841", "text": "RT @Array_P...
# Message published successfully.
# 2023-03-07 10:05:03.292669: writing message to cluster: {"id": "1633046027199471619", "text": "\ud83c\udf8...
# Message published successfully.
# 2023-03-07 10:05:03.294189: writing message to cluster: {"id": "1633046027161960448", "text": "RT @RimmuCr...
# Message published successfully.
# 2023-03-07 10:05:03.295675: writing message to cluster: {"id": "1633046027103277058", "text": "RT @Memory_...
# Message published successfully.
# 2023-03-07 10:05:03.297126: writing message to cluster: {"id": "1633046026914516993", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.298542: writing message to cluster: {"id": "1633046026683826176", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.300021: writing message to cluster: {"id": "1633046026532831232", "text": "\ud83c\udf8...
# Message published successfully.
# 2023-03-07 10:05:03.301518: writing message to cluster: {"id": "1633046026276995072", "text": "RT @gate_io...
# Message published successfully.
# 2023-03-07 10:05:03.303167: writing message to cluster: {"id": "1633046026268594177", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.304734: writing message to cluster: {"id": "1633046026151165954", "text": "RT @LunaHun...
# Message published successfully.
# 2023-03-07 10:05:03.306625: writing message to cluster: {"id": "1633046026100826112", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.308383: writing message to cluster: {"id": "1633046025471688707", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.309928: writing message to cluster: {"id": "1633046025446526976", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.311577: writing message to cluster: {"id": "1633046025173897217", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.313290: writing message to cluster: {"id": "1633046024687087621", "text": "0.2 $ETH Pr...
# Message published successfully.
# 2023-03-07 10:05:03.314834: writing message to cluster: {"id": "1633046024620048386", "text": "RT @Array_P...
# Message published successfully.
# 2023-03-07 10:05:03.316488: writing message to cluster: {"id": "1633046024293064704", "text": "\ud83c\udf8...
# Message published successfully.
# 2023-03-07 10:05:03.318138: writing message to cluster: {"id": "1633046023873650688", "text": "\ud83e\udd7...
# Message published successfully.
# 2023-03-07 10:05:03.319881: writing message to cluster: {"id": "1633046023680724992", "text": "\ud83d\udd2...
# Message published successfully.
# 2023-03-07 10:05:03.321601: writing message to cluster: {"id": "1633046023118667777", "text": "\ud83d\udcb...
# Message published successfully.
# 2023-03-07 10:05:03.323269: writing message to cluster: {"id": "1633046022896369664", "text": "RT @CoinWZH...
# Message published successfully.
# 2023-03-07 10:05:03.324910: writing message to cluster: {"id": "1633046022565007360", "text": "RT @Array_P...
# Message published successfully.
# 2023-03-07 10:05:03.326459: writing message to cluster: {"id": "1633046022455959552", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.328284: writing message to cluster: {"id": "1633046022338531328", "text": "RT @HabitTr...
# Message published successfully.
# 2023-03-07 10:05:03.330003: writing message to cluster: {"id": "1633046022103465991", "text": "RT @Hopus77...

# %% [markdown]
# ### Testing produced and consumed messages

# %%
# retrieve messages
consumed_messages = consume_xy(twitter_consumer, twitter_topic)

# testing if write & read operations work as intended
for i, message in enumerate(consumed_messages):
    assert message[1] == json.loads(test_array[i][1])
    assert message[0] == test_array[i][0]
print("Consumed messages match produced messages.")
# Out:
# Consumed 100 messages from Kafka Cluster
# Consumed messages match produced messages.
